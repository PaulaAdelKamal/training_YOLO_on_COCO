# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-221-gd07f9ce Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.11.0+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %% [markdown]
# Remove Test to Avoid Memory error from coco.

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data coco.yaml --weights '' --cfg yolov5s.yaml --cache
# Out:
# train: weights=, cfg=yolov5s.yaml, data=coco.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-221-gd07f9ce Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
import os
folder_paths =  os.listdir("/content/datasets/coco/images/train2017") 
folder_paths = folder_paths[:112287]

X = len(folder_paths)
for i in range (X) :
        try:
          os.remove('/content/datasets/coco/images/train2017' + "/" +folder_paths[i][:-4]+ '.jpg')
          os.remove('/content/datasets/coco/labels/train2017' + "/" +folder_paths[i][:-4] + '.txt')
        except FileNotFoundError as e:
            continue

# %%
X = os.listdir("/content/datasets/coco/labels/train2017")
y = os.listdir("/content/datasets/coco/images/train2017")
print (len(X),len(y))
# Out:
# 5953 6000

# %%
import os
folder_paths =  os.listdir("/content/datasets/coco/images/val2017") 
folder_paths = folder_paths[:4000]

X = len(folder_paths)
for i in range (X) :
        try:
          os.remove('/content/datasets/coco/images/val2017' + "/" +folder_paths[i][:-4]+ '.jpg')
          os.remove('/content/datasets/coco/labels/val2017' + "/" +folder_paths[i][:-4] + '.txt')
        except FileNotFoundError as e:
            continue

# %%
X = os.listdir("/content/datasets/coco/labels/val2017")
y = os.listdir("/content/datasets/coco/images/val2017")
print (len(X),len(y))
# Out:
# 992 1000

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data coco.yaml --weights '' --cfg yolov5s.yaml --cache
# Out:
# Streaming output truncated to the last 5000 lines.
# train: WARNING: /content/datasets/coco/images/train2017/000000019957.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/datasets/coco/images/train2017/000000019957.jpg'
# train: WARNING: /content/datasets/coco/images/train2017/000000019959.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/datasets/coco/images/train2017/000000019959.jpg'
# train: WARNING: /content/datasets/coco/images/train2017/000000019962.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/datasets/coco/images/train2017/000000019962.jpg'
# train: WARNING: /content/datasets/coco/images/train2017/000000019967.jpg: ignoring corrupt image/label: [Errno 2] No such file or directory: '/content/datasets/coco/images/train2017/000000019967.jpg'
# ...
